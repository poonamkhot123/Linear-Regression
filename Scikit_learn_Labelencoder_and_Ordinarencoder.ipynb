# %% [markdown]
# <a href="https://colab.research.google.com/github/poonamkhot123/Linear-Regression/blob/main/Scikit_learn_Labelencoder_and_Ordinarencoder.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("/content/CAR DETAILS FROM CAR DEKHO.csv")

# %%
df.head()
# Out:
#                        name  year  selling_price  km_driven    fuel  \
# 0             Maruti 800 AC  2007          60000      70000  Petrol
# 1  Maruti Wagon R LXI Minor  2007         135000      50000  Petrol
# 2      Hyundai Verna 1.6 SX  2012         600000     100000  Diesel
# 3    Datsun RediGO T Option  2017         250000      46000  Petrol
# 4     Honda Amaze VX i-DTEC  2014         450000     141000  Diesel
#
#   seller_type transmission         owner
# 0  Individual       Manual   First Owner
# 1  Individual       Manual   First Owner
# 2  Individual       Manual   First Owner
# 3  Individual       Manual   First Owner
# 4  Individual       Manual  Second Owner

# %% [markdown]
# # **Using Python**

# %%
# df.drop("name",axis=1,inplace=True)

# %%
# df
# Out:
#       year  selling_price  km_driven    fuel seller_type transmission  \
# 0     2007          60000      70000  Petrol  Individual       Manual
# 1     2007         135000      50000  Petrol  Individual       Manual
# 2     2012         600000     100000  Diesel  Individual       Manual
# 3     2017         250000      46000  Petrol  Individual       Manual
# 4     2014         450000     141000  Diesel  Individual       Manual
# ...    ...            ...        ...     ...         ...          ...
# 4335  2014         409999      80000  Diesel  Individual       Manual
# 4336  2014         409999      80000  Diesel  Individual       Manual
# 4337  2009         110000      83000  Petrol  Individual       Manual
# 4338  2016         865000      90000  Diesel  Individual       Manual
# 4339  2016         225000      40000  Petrol  Individual       Manual
#
#              owner
# 0      First Owner
# 1      First Owner
# 2      First Owner
# 3      First Owner
# 4     Second Owner
# ...            ...
# 4335  Second Owner
# 4336  Second Owner
# 4337  Second Owner
# 4338   First Owner
# 4339   First Owner
#
# [4340 rows x 7 columns]

# %%
# df['transmission'].value_counts()
# Out:
# transmission
# Manual       3892
# Automatic     448
# Name: count, dtype: int64

# %%
# df['transmission']=df['transmission'].map({'Manual':0,'Automatic':1})

# %%
# df.sample(5)
# Out:
#       year  selling_price  km_driven    fuel seller_type transmission  \
# 781   2017         450000      50000  Petrol  Individual    Automatic
# 3492  2019         475000     105000  Diesel      Dealer    Automatic
# 462   2012         350000      77000  Diesel  Individual       Manual
# 2165  2014         390000      90000  Diesel  Individual       Manual
# 2870  2006          85000      60000  Petrol  Individual       Manual
#
#              owner  tans_new
# 781    First Owner         1
# 3492   First Owner         1
# 462    First Owner         0
# 2165   First Owner         0
# 2870  Second Owner         0

# %%
df['seller_type'].value_counts()
# Out:
# seller_type
# Individual          3244
# Dealer               994
# Trustmark Dealer     102
# Name: count, dtype: int64

# %%
# df['seller_type'] = df['seller_type'].map({'Individual':0,'Dealer':1,'Trustmark Dealer':2})

# %%
# df.sample(5)
# Out:
#       year  selling_price  km_driven    fuel       seller_type transmission  \
# 1237  2008         170000      81324  Petrol            Dealer       Manual
# 1559  2012         550000     120000  Diesel        Individual       Manual
# 1031  2017        2600000      47162  Diesel  Trustmark Dealer    Automatic
# 4266  2016         630000      55000  Diesel            Dealer       Manual
# 762   2017         290000      20000  Petrol        Individual       Manual
#
#              owner  tans_new  seller_new
# 1237   First Owner         0           1
# 1559  Second Owner         0           0
# 1031   First Owner         1           2
# 4266   First Owner         0           1
# 762    First Owner         0           0

# %% [markdown]
# # **Using Scikitlearn**

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(df.drop('fuel',axis=1),df['fuel'],test_size=0.2,random_state=42)

# %%
X_train
# Out:
#       year  selling_price  km_driven  seller_type  transmission         owner  \
# 227   2017        1500000      20000            0             0   First Owner
# 964   2018         500000      50000            0             0   First Owner
# 2045  2013          92800      25000            0             0  Second Owner
# 1025  2011          95000      70000            0             0   First Owner
# 4242  2017         685000      72000            1             0   First Owner
# ...    ...            ...        ...          ...           ...           ...
# 3444  2006         500000      50000            0             0   First Owner
# 466   2011         133000      80000            0             0   First Owner
# 3092  2016         665000      51000            1             0   First Owner
# 3772  2013         250999      80000            0             0   First Owner
# 860   2013         175000      80000            0             0   First Owner
#
#       tans_new  seller_new
# 227          0           0
# 964          0           0
# 2045         0           0
# 1025         0           0
# 4242         0           1
# ...        ...         ...
# 3444         0           0
# 466          0           0
# 3092         0           1
# 3772         0           0
# 860          0           0
#
# [3472 rows x 8 columns]

# %%
X_test
# Out:
#       year  selling_price  km_driven  seller_type  transmission         owner  \
# 3978  2010         165000      80000            0             0   First Owner
# 1448  2019         250000      27000            0             0   First Owner
# 2664  2008         120000      41723            0             0  Second Owner
# 17    2014         450000     141000            0             0  Second Owner
# 1634  2016         730000      60000            0             1  Second Owner
# ...    ...            ...        ...          ...           ...           ...
# 3468  2007         130000      60000            0             0   Third Owner
# 3164  2015         350000     120000            0             0   First Owner
# 416   2011         150000      40000            0             0  Second Owner
# 1616  2017         650000       6480            2             0   First Owner
# 2480  2019         575000      30000            1             0   First Owner
#
#       tans_new  seller_new
# 3978         0           0
# 1448         0           0
# 2664         0           0
# 17           0           0
# 1634         1           0
# ...        ...         ...
# 3468         0           0
# 3164         0           0
# 416          0           0
# 1616         0           2
# 2480         0           1
#
# [868 rows x 8 columns]

# %%
y_train
# Out:
# 227     Diesel
# 964     Diesel
# 2045    Petrol
# 1025    Diesel
# 4242    Diesel
#          ...
# 3444    Diesel
# 466     Diesel
# 3092    Diesel
# 3772    Diesel
# 860     Petrol
# Name: fuel, Length: 3472, dtype: object

# %%
y_test
# Out:
# 3978    Diesel
# 1448    Petrol
# 2664    Petrol
# 17      Diesel
# 1634    Diesel
#          ...
# 3468    Petrol
# 3164    Diesel
# 416     Diesel
# 1616    Petrol
# 2480    Petrol
# Name: fuel, Length: 868, dtype: object

# %% [markdown]
# # **Using Scikitlearn**

# %%
from sklearn.preprocessing import LabelEncoder,OrdinalEncoder

# %% [markdown]
# # **1.Applying Label Encoder**

# %%
le = LabelEncoder()

# %%
y_train_scaled = le.fit_transform(y_train)
y_test_scaled = le.transform(y_test)

# %%
df['fuel'].value_counts()
# Out:
# fuel
# Diesel      2153
# Petrol      2123
# CNG           40
# LPG           23
# Electric       1
# Name: count, dtype: int64

# %%
y_train_scaled
# Out:
# array([1, 1, 4, ..., 1, 1, 4])

# %%
X_train
# Out:
#       year  selling_price  km_driven  seller_type  transmission         owner  \
# 227   2017        1500000      20000            0             0   First Owner
# 964   2018         500000      50000            0             0   First Owner
# 2045  2013          92800      25000            0             0  Second Owner
# 1025  2011          95000      70000            0             0   First Owner
# 4242  2017         685000      72000            1             0   First Owner
# ...    ...            ...        ...          ...           ...           ...
# 3444  2006         500000      50000            0             0   First Owner
# 466   2011         133000      80000            0             0   First Owner
# 3092  2016         665000      51000            1             0   First Owner
# 3772  2013         250999      80000            0             0   First Owner
# 860   2013         175000      80000            0             0   First Owner
#
#       tans_new  seller_new
# 227          0           0
# 964          0           0
# 2045         0           0
# 1025         0           0
# 4242         0           1
# ...        ...         ...
# 3444         0           0
# 466          0           0
# 3092         0           1
# 3772         0           0
# 860          0           0
#
# [3472 rows x 8 columns]

# %%
oe = OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1)
X_train_scaled = oe.fit_transform(X_train)
X_test_scaled = oe.transform(X_test)

# %%
X_train_scaled
# Out:
# array([[ 23., 350., 114., ...,   0.,   0.,   0.],
#        [ 24., 187., 294., ...,   0.,   0.,   0.],
#        [ 19.,  33., 141., ...,   2.,   0.,   0.],
#        ...,
#        [ 22., 229., 298., ...,   0.,   0.,   1.],
#        [ 19., 101., 453., ...,   0.,   0.,   0.],
#        [ 19.,  69., 453., ...,   0.,   0.,   0.]])
